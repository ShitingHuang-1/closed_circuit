# %%
import numpy as np
import matplotlib.pyplot as plt
from heart import heart

# %%
 T=60/75
lv=heart(tau1 = 0.2*T, tau2 = 0.48*T, # tau1,2 (s)
         m1 = 4, m2 = 20, # m1,2
         Emax = 0.1,Emin = 0.08, # Emax,min (mmHg/mL)
        V0 = 10,T = T)# V0 (mL), T (s)

# %%
lvE=[]
ti=[]
for i in np.arange(0,20,0.001):
    ti.append(i)
    lvE.append(lv.Et(i))
plt.plot(ti, lvE)
plt.xlim(11.2,11.8)
plt.show()
