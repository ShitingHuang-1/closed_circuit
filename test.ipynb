# %%
import numpy as np
import scipy as sp
import sympy
import math
import matplotlib.pyplot as plt
from heart import *

# %%
T=0.8
a=heart(0.269*T,0.452*T,1.32,27.4,0.6,0.04,20*10**(-9),55)
#tau1,tau2,m1,m2,Emax,Emin,Ks,V0

# %%
delta_t=0.001
t=np.arange(0,14,delta_t)
vt=(-69.51672*np.cos(7.85398*t)+180)
dvdt=546*np.sin((2*math.pi/T)*t)
dqdt=4288.2739*np.cos(7.85398*t)

# %%
pt=[]
Et=[]
Rs=[]
for i in range(len(t)):
    pt.append(a.p(vt[i],dvdt[i],t[i]))
    Et.append(a.Et(t[i]))
    Rs.append(a.Rs(vt[i],t[i]))
#pt=pt[400:1400]

# %%
fig,axs = plt.subplots(3,1,sharex=True)
axs[0].plot(t,pt)
axs[1].plot(t, Et)
axs[2].plot(t, vt)
#plt.xlim(4, 7)  # setting x scale
#plt.ylim(4, 6)  
plt.show()

# %%
plt.plot(t,Et)
#plt.xlim(4, 7)  # setting x scale
#plt.ylim(4, 6)  
plt.show()

# %%
import numpy as np
import scipy as sp
import sympy
import math
import matplotlib.pyplot as plt
import valve

# %%
b=valve.Valve(1.06,1,1,0.03,0.04,10,18.2,0)
#density, eff_length, Aann, Kvo,Kvc,p_oc,q,diff_q
delta_t=0.001
t=np.arange(0,3,delta_t)
T=0.8
dvdt=[]
dqdt=[]
for ti in t:
    ti=ti%T
    if ti<=T/2. and ti>=0:
        dvdt.append(81.9*np.sin((2*math.pi/T)*ti))
        dqdt.append(643.239*np.cos(7.85398*ti))
    else:
        dvdt.append(0)
        dqdt.append(0)

# %%
final=[]
x=[]
for i in range(len(dvdt)):
    final.append(b.delta_p(dvdt[i],dqdt[i],t[i]))
    #print(b.xi_t(t[i]))
    x.append(b.xi_t(t[i]))

# %%
plt.plot(t,x)
#plt.xlim(0.9, 1.5)  # setting x scale
#plt.ylim(1, 2)  
plt.show()
